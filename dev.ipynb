# %%
from pathlib import Path
from alshicrypt import generate

result = generate(
    image_dir=Path("samples/images"),
    audio_dir=Path("samples/audio/wav"),  # leave as-is, but…
    num_train_images=4000,
    num_train_audio=0,
    num_test_images=25,
    num_test_audio=0,
    device="cuda",
)

print("Encryptor:", result.encrypt_stats)
print("Decryptor:", result.decrypt_stats)
# Out:
# encryptor epoch 1: accuracy=0.000
# encryptor epoch 2: accuracy=0.000
# encryptor epoch 3: accuracy=0.000
# encryptor epoch 4: accuracy=0.000
# encryptor epoch 5: accuracy=0.000
# encryptor epoch 6: accuracy=0.000
# encryptor epoch 7: accuracy=0.000
# encryptor epoch 8: accuracy=0.000
# encryptor epoch 9: accuracy=0.000
# encryptor epoch 10: accuracy=0.000
# encryptor epoch 11: accuracy=0.000
# encryptor epoch 12: accuracy=0.000
# encryptor epoch 13: accuracy=0.000
# encryptor epoch 14: accuracy=0.000
# encryptor epoch 15: accuracy=0.000
# encryptor epoch 16: accuracy=0.000
# encryptor epoch 17: accuracy=0.000
# encryptor epoch 18: accuracy=0.000
# encryptor epoch 19: accuracy=0.000
# encryptor epoch 20: accuracy=0.000
# encryptor epoch 21: accuracy=0.000
# encryptor epoch 22: accuracy=0.000
# encryptor epoch 23: accuracy=0.000
# encryptor epoch 24: accuracy=0.000
# encryptor epoch 25: accuracy=0.000
# encryptor epoch 26: accuracy=0.000
# encryptor epoch 27: accuracy=0.000
# ...
